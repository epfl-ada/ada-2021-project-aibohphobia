# %%
import numpy as np
import pandas as pd
from tld import get_tld
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import string
from nltk.corpus import stopwords
import math
from collections import Counter
from operator import itemgetter
import re
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/selene/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/selene/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### Load data

# %%
DATA_PATH = 'data/'
FILE_PATH = DATA_PATH + 'quotes-2019-domains.json.bz2'
OLD_PATH = DATA_PATH + 'quotes-2019.json.bz2'

# %%
def process_chunk(chunk):
        print(f'Processing chunk with {len(chunk)} rows')
        print(chunk.columns)

with pd.read_json(FILE_PATH, lines=True, compression='bz2', chunksize=1000000) as df_reader:
    for chunk in df_reader:
        process_chunk(chunk)

# %% [markdown]
# ### Partially reading data (with already extracted domains)

# %%
df_test = pd.read_json(FILE_PATH, lines=True, compression='bz2', nrows=100)
df_test.head()
# Out:
#              quoteID                                          quotation  \
# 0  2019-10-14-000009  % 9: D: D @? 6 H2J H6 E9@F89E H6 4@F=5 8: G6 3...
# 1  2019-04-08-048753       It is immoral. It is harmful. It is hurtful.
# 2  2019-07-17-000030        [ Amber ] loves her son more than anything,
# 3  2019-05-15-053302  It is important for our equine science student...
# 4  2019-04-20-000011  ... an Afrikaans family living in South Africa...
#
#                   speaker         qids                date  numOccurrences  \
# 0                    None           [] 2019-10-14 07:30:00               1
# 1  President Donald Trump     [Q22686] 2019-04-08 16:22:00              44
# 2                    None           [] 2019-07-17 22:54:35               1
# 3           Sally Johnson  [Q42336656] 2019-05-15 18:03:22               1
# 4                    None           [] 2019-04-20 22:30:57               1
#
#                                               probas  \
# 0          [[None, 0.5595], [Julio Morales, 0.4405]]
# 1  [[President Donald Trump, 0.5802], [None, 0.36...
# 2         [[None, 0.8276], [Amber Portwood, 0.1724]]
# 3          [[Sally Johnson, 0.5721], [None, 0.4279]]
# 4               [[None, 0.8331], [you long, 0.1669]]
#
#                                                 urls phase  \
# 0  [http://www.ivpressonline.com/news/local/ivc-f...     E
# 1  [https://www.mercedsunstar.com/news/business/a...     E
# 2  [https://www.inquisitr.com/5535969/did-amber-p...     E
# 3  [https://www.lanereport.com/113381/2019/05/qua...     E
# 4     [http://filmthreat.com/reviews/the-harvester/]     E
#
#                                              domains
# 0                                              [com]
# 1  [com, com, com, com, com, com, com, com, com, ...
# 2                                              [com]
# 3                                              [com]
# 4                                              [com]

# %% [markdown]
# ### Extract site name

# %%
def get_sitename(url):
    res = get_tld(url, as_object=True)
    return res.domain

# %%
def extract_name(df): 
    df['sitenames'] = np.nan
    for row in range(df.shape[0]):
        df['sitenames'][row] = [get_sitename(site) for site in df['urls'][row]]

# %%
extract_name(df_test)
df_test.head()
# Out:
# /var/folders/pz/kh7ycnhs1d35h6q5tq_vg4k80000gn/T/ipykernel_5847/3767297332.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sitenames'][row] = [get_sitename(site) for site in df['urls'][row]]
# /opt/anaconda3/envs/ada-project/lib/python3.8/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#              quoteID                                          quotation  \
# 0  2019-10-14-000009  % 9: D: D @? 6 H2J H6 E9@F89E H6 4@F=5 8: G6 3...
# 1  2019-04-08-048753       It is immoral. It is harmful. It is hurtful.
# 2  2019-07-17-000030        [ Amber ] loves her son more than anything,
# 3  2019-05-15-053302  It is important for our equine science student...
# 4  2019-04-20-000011  ... an Afrikaans family living in South Africa...
#
#                   speaker         qids                date  numOccurrences  \
# 0                    None           [] 2019-10-14 07:30:00               1
# 1  President Donald Trump     [Q22686] 2019-04-08 16:22:00              44
# 2                    None           [] 2019-07-17 22:54:35               1
# 3           Sally Johnson  [Q42336656] 2019-05-15 18:03:22               1
# 4                    None           [] 2019-04-20 22:30:57               1
#
#                                               probas  \
# 0          [[None, 0.5595], [Julio Morales, 0.4405]]
# 1  [[President Donald Trump, 0.5802], [None, 0.36...
# 2         [[None, 0.8276], [Amber Portwood, 0.1724]]
# 3          [[Sally Johnson, 0.5721], [None, 0.4279]]
# 4               [[None, 0.8331], [you long, 0.1669]]
#
#                                                 urls phase  \
# 0  [http://www.ivpressonline.com/news/local/ivc-f...     E
# 1  [https://www.mercedsunstar.com/news/business/a...     E
# 2  [https://www.inquisitr.com/5535969/did-amber-p...     E
# 3  [https://www.lanereport.com/113381/2019/05/qua...     E
# 4     [http://filmthreat.com/reviews/the-harvester/]     E
#
#                                              domains  \
# 0                                              [com]
# 1  [com, com, com, com, com, com, com, com, com, ...
# 2                                              [com]
# 3                                              [com]
# 4                                              [com]
#
#                                            sitenames
# 0                                    [ivpressonline]
# 1  [mercedsunstar, sacbee, mynorthwest, lasvegass...
# 2                                        [inquisitr]
# 3                                       [lanereport]
# 4                                       [filmthreat]

# %% [markdown]
# ### Extract domain and sitename for whole .json file
# #### Careful : can take >1hr per file
# - Will read the raw file
# - Will write into new .json file
# - Change the paths to adapt to local setup

# %%
def get_domain(url):
    res = get_tld(url, as_object=True)
    return res.tld

def get_sitename(url):
    res = get_tld(url, as_object=True)
    return res.domain

# %%
import bz2
import json

path_to_file = 'data/quotes-2019.json.bz2' 
path_to_out = 'data/quotes-2019-domains-names.json.bz2'

with bz2.open(path_to_file, 'rb') as s_file:
    with bz2.open(path_to_out, 'wb') as d_file:
        for instance in s_file:
            instance = json.loads(instance) # loading a sample
            urls = instance['urls'] # extracting list of links
            domains = []
            sitenames = []
            for url in urls:
                tld = get_domain(url)
                name = get_sitename(url)
                domains.append(tld)
                sitenames.append(name)
            instance['domains'] = domains # updating the sample with domain name
            instance['sitenames'] = sitenames
            d_file.write((json.dumps(instance)+'\n').encode('utf-8')) # writing in the new file

# %% [markdown]
# ## Task 3: Manually select websites to keep (that have always have a same specific topic)

# %%
df_test2 = pd.read_json(FILE_PATH, lines=True, compression='bz2', nrows=10000)

# %%
extract_name(df_test2)
df_test2.head()
# Out:
# /var/folders/pz/kh7ycnhs1d35h6q5tq_vg4k80000gn/T/ipykernel_5847/3767297332.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sitenames'][row] = [get_sitename(site) for site in df['urls'][row]]
# /opt/anaconda3/envs/ada-project/lib/python3.8/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#              quoteID                                          quotation  \
# 0  2019-10-14-000009  % 9: D: D @? 6 H2J H6 E9@F89E H6 4@F=5 8: G6 3...
# 1  2019-04-08-048753       It is immoral. It is harmful. It is hurtful.
# 2  2019-07-17-000030        [ Amber ] loves her son more than anything,
# 3  2019-05-15-053302  It is important for our equine science student...
# 4  2019-04-20-000011  ... an Afrikaans family living in South Africa...
#
#                   speaker         qids                date  numOccurrences  \
# 0                    None           [] 2019-10-14 07:30:00               1
# 1  President Donald Trump     [Q22686] 2019-04-08 16:22:00              44
# 2                    None           [] 2019-07-17 22:54:35               1
# 3           Sally Johnson  [Q42336656] 2019-05-15 18:03:22               1
# 4                    None           [] 2019-04-20 22:30:57               1
#
#                                               probas  \
# 0          [[None, 0.5595], [Julio Morales, 0.4405]]
# 1  [[President Donald Trump, 0.5802], [None, 0.36...
# 2         [[None, 0.8276], [Amber Portwood, 0.1724]]
# 3          [[Sally Johnson, 0.5721], [None, 0.4279]]
# 4               [[None, 0.8331], [you long, 0.1669]]
#
#                                                 urls phase  \
# 0  [http://www.ivpressonline.com/news/local/ivc-f...     E
# 1  [https://www.mercedsunstar.com/news/business/a...     E
# 2  [https://www.inquisitr.com/5535969/did-amber-p...     E
# 3  [https://www.lanereport.com/113381/2019/05/qua...     E
# 4     [http://filmthreat.com/reviews/the-harvester/]     E
#
#                                              domains  \
# 0                                              [com]
# 1  [com, com, com, com, com, com, com, com, com, ...
# 2                                              [com]
# 3                                              [com]
# 4                                              [com]
#
#                                            sitenames
# 0                                    [ivpressonline]
# 1  [mercedsunstar, sacbee, mynorthwest, lasvegass...
# 2                                        [inquisitr]
# 3                                       [lanereport]
# 4                                       [filmthreat]

# %%
all_sites = pd.Series([x for row in df_test2['sitenames'] for x in row])
sites = all_sites.drop_duplicates(keep='first')

# %%
for item in sites:
    print(item)
# Out:
# ivpressonline
# mercedsunstar
# sacbee
# mynorthwest
# lasvegassun
# wtop
# ctpost
# kdhnews
# newstimes
# registercitizen
# stamfordadvocate
# wftv
# expressnews
# fairfieldcitizenonline
# nhregister
# thehour
# wpxi
# wsbtv
# wsoctv
# thestarphoenix
# infotel
# citynews
# 570news
# news965
# startribune
# indiatimes
# wibx950
# bradenton
# theolympian
# charlotteobserver
# heraldonline
# businessinsider
# smdailyjournal
# wthr
# chron
# cbsnews
# msn
# nbc-2
# bostonglobe
# business-standard
# inquisitr
# lanereport
# filmthreat
# kstp
# comicbook
# 9news
# marketwatch
# inews
# eastidahonews
# thesun
# theepochtimes
# geek
# mamamia
# wordpress
# vanityfair
# ipolitics
# wdtv
# maxim
# fox29
# breakingisraelnews
# etcanada
# westernjournal
# bizpacreview
# salon
# nypost
# atimes
# prisonplanet
# independent
# express
# sudbury
# newuniversity
# timescolonist
# teenvogue
# nashvillescene
# bordermail
# ottawasun
# channel3000
# cnbc
# zawya
# canada
# hellenicshippingnews
# tubefilter
# crn
# kstatecollegian
# fastcoexist
# billboard
# complex
# newshub
# atlantablackstar
# jezebel
# thestar
# pulse
# breitbart
# upstreamonline
# perezhilton
# miragenews
# mitchellrepublic
# jamestownsun
# bemidjipioneer
# duluthnewstribune
# thedickinsonpress
# brainerddispatch
# inforum
# eveningtimes
# thenational
# standardmedia
# irishmirror
# mirror
# news24
# speedcafe
# 90min
# andoveradvertiser
# basildonrecorder
# basingstokegazette
# bracknellnews
# braintreeandwithamtimes
# heraldseries
# iwcp
# newsandstar
# northwalespioneer
# prestwichandwhitefieldguide
# readingchronicle
# southwalesguardian
# tewkesburyadmag
# thelancasterandmorecambecitizen
# timesandstar
# wiltshirebusinessonline
# asianimage
# banburycake
# bournemouthecho
# bromsgroveadvertiser
# bucksfreepress
# burnhamandhighbridgeweeklynews
# campaignseries
# chardandilminsternews
# chelmsfordweeklynews
# clactonandfrintongazette
# croydonguardian
# dorsetecho
# droitwichadvertiser
# dudleynews
# ealingtimes
# echo-news
# epsomguardian
# eveshamjournal
# gazetteandherald
# guardian-series
# halesowennews
# knutsfordguardian
# lancashiretelegraph
# leighjournal
# malverngazette
# messengernewspapers
# middevonstar
# newsnorthwales
# newsshopper
# northwichguardian
# oxfordmail
# penarthtimes
# somersetcountygazette
# southendstandard
# southwalesargus
# sthelensstar
# stourbridgenews
# stroudnewsandjournal
# theargus
# thenorthernecho
# thetelegraphandargus
# thewestmorlandgazette
# thisislancashire
# thisislocallondon
# thisisthewestcountry
# thisiswiltshire
# wandsworthguardian
# warringtonguardian
# watfordobserver
# wiltsglosstandard
# wiltshiretimes
# winsfordguardian
# wirralglobe
# worcesternews
# yeovilexpress
# yorkpress
# yourlocalguardian
# expressandstar
# sportsmole
# ncregister
# architecturaldigest
# theatlantic
# behindthesteelcurtain
# snopes
# thequint
# hindustantimes
# cbs8
# justjaredjr
# realitytvworld
# popsugar
# hellomagazine
# eonline
# etonline
# ksat
# albawaba
# theloop
# aaj
# thehansindia
# theborneopost
# nbcconnecticut
# nationalinterest
# football-oranje
# eenews
# juneesoutherncross
# sify
# scroll
# fresnobee
# khon2
# elle
# scotsman
# wsws
# channelstv
# browndailyherald
# illawarramercury
# newsmax
# metro
# standard
# straitstimes
# firstpost
# morungexpress
# thepeninsulaqatar
# arynews
# theweek
# insurancenewsnet
# tbo
# telegraph
# churchmilitant
# brentwoodweeklynews
# hillingdontimes
# kidderminstershuttle
# nwemail
# romseyadvertiser
# barryanddistrictnews
# bordercountiesadvertizer
# bridgwatermercury
# burytimes
# carrickherald
# cravenherald
# creweguardian
# dailyecho
# enfieldindependent
# freepressseries
# halsteadgazette
# hampshirechronicle
# herefordtimes
# ledburyreporter
# localberkshire
# maldonandburnhamstandard
# redditchadvertiser
# richmondandtwickenhamtimes
# surreycomet
# swindonadvertiser
# theboltonnews
# westerntelegraph
# wimbledonguardian
# windsorobserver
# witneygazette
# thelondoneconomic
# go
# financialexpress
# statetimes
# kingfut
# asu
# intoday
# businesstoday
# theadvocate
# cnn
# pga
# kansascity
# radio
# northcoastnow
# winnipegfreepress
# spin
# postindependent
# dcourier
# faribaultcountyregister
# cbslocal
# syracuse
# sportstalkflorida
# theneworleansadvocate
# foxbusiness
# onwardstate
# tapinto
# kusi
# timesofsandiego
# blastmagazine
# wnmufm
# wqcs
# wuwf
# wxxinews
# news-medical
# saukvalley
# appeal-democrat
# hartfordbusiness
# rollingstone
# oup
# revelist
# fansided
# suntimes
# afaqs
# sandiegouniontribune
# calgarysun
# edmontonsun
# thehindubusinessline
# ajot
# finance-commerce
# tempo
# nzcity
# leadership
# manningrivertimes
# kwch
# aninews
# sunnewsonline
# travelweekly
# thedailynewsonline
# screendaily
# brooklyneagle
# spectator
# vpr
# nbc12
# wdbj7
# 6abc
# abc13
# abc30
# abc7
# abc7chicago
# abc7news
# abc7ny
# thedailybeast
# examiner
# al-monitor
# timesofmalta
# digitaljournal
# newsweekpakistan
# 27east
# thehindu
# dvidshub
# allafrica
# psu
# houstonchronicle
# djcoregon
# myedmondsnews
# dailyorange
# mercopress
# moderntiredealer
# sportsbusinessdaily
# carltonfc
# typepad
# skysports
# tribalfootball
# 360nobs
# washingtoncitypaper
# aol
# ardrossanherald
# bicesteradvertiser
# harrowtimes
# harwichandmanningtreestandard
# smallholder
# gazette-news
# rhyljournal
# sloughobserver
# times-series
# oxfordtimes
# salinapost
# staradvertiser
# nationalrighttolifenews
# thefix
# variety
# wsbradio
# idahocountyfreepress
# wonderwall
# hellobeautiful
# monstersandcritics
# cleveland19
# sierrasun
# tahoedailytribune
# orissapost
# naharnet
# arabianbusiness
# mg
# easternmirrornagaland
# timesofoman
# thesundaily
# theshillongtimes
# gg2
# deccanchronicle
# tass
# dw
# batemansbaypost
# roanecounty
# clubcall
# collegian
# wesleyan
# stlouisrams
# kamloopsthisweek
# bernama
# insideclimatenews
# premier
# lcnewschronicle
# ehextra
# fultonsun
# rosemounttownpages
# inc
# vogue
# montrealgazette
# centraltelegraph
# noosanews
# westhawaiitoday
# morningstar
# irishexaminer
# breakingnews
# weaselzippers
# gopusa
# financialpost
# thebusinessjournal
# pjmedia
# vanguardngr
# autocar
# kfvs12
# dailycamera
# americanbanker
# officer
# instinctmagazine
# wral
# kyma
# sltrib
# parade
# sunderlandecho
# businesslive
# walesonline
# oregonwinepress
# fourfourtwo
# soccerladuma
# abplive
# wtvy
# fiercewireless
# geelongadvertiser
# arnnet
# worldboxingnews
# buckinghamtoday
# daytondailynews
# whio
# mlb
# businesstimes
# calgaryherald
# bdnews24
# stabroeknews
# algemeiner
# news3lv
# newpittsburghcourieronline
# kirotv
# fox23
# localsyr
# mystateline
# koin
# myarklamiss
# mychamplainvalley
# wvnstv
# bostonherald
# artesianews
# journal-news
# mydaytondailynews
# altoonamirror
# cleveland
# sunshinestatenews
# orlandoweekly
# cltampa
# nba
# wbfo
# cpfc
# cumberlandnewsnow
# thevanguard
# trurodaily
# mashable
# whmi
# atpworldtour
# sport
# gisborneherald
# newarkadvertiser
# wpsdlocal6
# usatoday
# 9and10news
# wqow
# kwwl
# wbng
# wxow
# columbiamissourian
# wsiltv
# kfgo
# wnax
# gizmodo
# myajc
# ewn
# bainbridgereview
# washingtonexaminer
# insideindianabusiness
# navy
# springfieldnewssun
# timesfreepress
# wdef
# montereyherald
# eveningnews24
# bustle
# femalefirst
# arkansasonline
# fastcodesign
# realclearpolitics
# rediff
# tennisworldusa
# kcby
# ennisdailynews
# blabbermouth
# dailydot
# masnsports
# derbyshiretimes
# theboot
# signalscv
# atlantadailyworld
# mcknights
# bnn
# thebull
# rappler
# moneycontrol
# afr
# spacedaily
# aljazeera
# taskandpurpose
# minnlawyer
# fool
# zacks
# nhl
# vox
# canindia
# prokerala
# thestatesman
# lfpress
# wmnf
# lalate
# canberratimes
# theroar
# timesnownews
# catholicnews
# catholicsun
# yorkshirepost
# sciencebusiness
# politicususa
# wsau
# gainesvilletimes
# americamagazine
# bridgemi
# winnipegsun
# cm-life
# postandcourier
# denofgeek
# sailingscuttlebutt
# dailyfreepress
# gothamist
# newcastlestar
# islandpacket
# australiantimes
# entertainmentdaily
# cbr
# wdio
# altondailynews
# recordernews
# necn
# theleader
# screenrant
# wtmj
# sgvtribune
# buzzfeed
# nextshark
# ozy
# digitalspy
# newsnation
# whtimes
# villagesoup
# gothamgazette
# businessreport
# axios
# nine
# goldderby
# molawyersmedia
# hollywoodreporter
# wsaw
# wigantoday
# justjared
# freshplaza
# dallasnews
# smithsonianmag
# realitytea
# bellinghamherald
# sportsnet
# leaderpost
# sherdog
# maritime-executive
# crainsdetroit
# lifenews
# 247sports
# wired
# ghanasoccernet
# eaglevalleynews
# wholehogsports
# bclocalnews
# gazettelive
# pr
# bsndenver
# missourinet
# hawaiipublicradio
# hpr2
# nepr
# peconicpublicbroadcasting
# wosu
# wpsu
# wnpr
# krwg
# kunc
# nhpr
# npr
# wfdd
# courthousenews
# americansongwriter
# straight
# kron4
# krqe
# wwlp
# everythinglubbock
# illinoishomepage
# keloland
# wowktv
# essentialretail
# ahmedabadmirror
# bangaloremirror
# pinkvilla
# hoganstand
# nesn
# newtondailynews
# broadsheet
# thinkadvisor
# liberal
# twtd
# yaleclimateconnections
# edmontonjournal
# bridportnews
# salisburyjournal
# dunfermlinepress
# eppingforestguardian
# leaderlive
# milfordmercury
# northwaleschronicle
# thesunchronicle
# ok
# cnet
# cosmicbooknews
# entertainment
# cosmopolitan
# eveningecho
# mid-day
# greenfieldreporter
# navytimes
# ucobserver
# dailydemocrat
# redwoodtimes
# santacruzsentinel
# mlive
# theringer
# rd
# hamodia
# xinhuanet
# timesheraldonline
# cnnphilippines
# pbs
# dailyexpress
# saipantribune
# vancouversun
# citizen
# actionnewsnow
# stokesentinel
# truckinginfo
# taipeitimes
# setanta
# newsatden
# wrdw
# bohemian
# buffalonews
# capenews
# pitpass
# formulaspy
# baltimoreravens
# chatsports
# wbez
# clickondetroit
# kvewtv
# designnews
# toofab
# cp24
# arlnow
# santafenewmexican
# newsroom
# greenleft
# theintelligencer
# adage
# kidspot
# mynewsla
# mirrorspectator
# cbssports
# newsbusters
# dazeddigital
# artforum
# wistv
# iowastatedaily
# mo4ch
# theroot
# itbusinessnet
# nation
# hpherald
# clevelandbanner
# indiannewslink
# twitchy
# stgeorgeutah
# lsusports
# hollywoodlife
# kyivpost
# patriotpost
# aish
# basketballinsiders
# indileak
# thenewsminute
# dayafterindia
# fox2detroit
# klaw
# christianpost
# amsterdamnews
# jacksonfreepress
# dailyexcelsior
# geo
# cardiovascularbusiness
# jhunewsletter
# nasaspaceflight
# abbynews
# albernivalleynews
# campbellrivermirror
# clearwatertimes
# cowichanvalleycitizen
# hopestandard
# lakecountrycalendar
# mapleridgenews
# pqbnews
# saanichnews
# summerlandreview
# terracestandard
# theprogress
# vernonmorningstar
# vicnews
# soundersfc
# thehockeywriters
# themarysue
# aim
# gpb
# southeastfarmpress
# bigrigs
# flatheadbeacon
# thesouthafrican
# piratefm
# sciencecodex
# cortezjournal
# mynews13
# wsvn
# businessmirror
# njbiz
# greatlakesadvocate
# herald-dispatch
# goodhousekeeping
# centralbanking
# fxweek
# whec
# abcnews4
# bakersfieldnow
# cbs6albany
# cnycentral
# fox17
# foxsanantonio
# kboi2
# keprtv
# keyetv
# kfoxtv
# kimatv
# kmph
# krcrtv
# ktul
# ktxs
# local15tv
# local21news
# okcfox
# upnorthlive
# wcyb
# weartv
# wjactv
# wjla
# wsbt
# wtov9
# wwmt
# fox28
# kmmsam
# eldoradonews
# wset
# waow
# wkow
# wvva
# wokv
# abc11
# wcjb
# wmbfnews
# kspr
# ky3
# wwaytv3
# whsv
# hawaiitribune-herald
# jewishjournal
# worldscreen
# universityworldnews
# entrepreneur
# lifezette
# dailycaller
# timesnews
# zdnet
# wndu
# ellwoodcityledger
# devex
# eurweb
# natureworldnews
# vvdailypress
# schoolsweek
# ttgmedia
# diverseeducation
# carwale
# swxrightnow
# thereader
# thedrinksbusiness
# kamcity
# kltv
# nybooks
# indiablooms
# socialitelife
# techtarget
# grenfellrecord
# jantakareporter
# thejournal
# inlander
# curbed
# kunr
# hotpress
# chicagodefender
# stlpublicradio
# capeandislands
# indyweek
# carbonbrief
# gilmermirror
# theparisnews
# rivals
# baltimorepostexaminer
# defenseone
# kickoff
# vocm
# kusports
# milb
# wafb
# katc
# arklatexhomepage
# 973espn
# huntnewsnu
# theherald-news
# mysuburbanlife
# daily-chronicle
# pressboxonline
# comicbookmovie
# outsports
# military
# smarteranalyst
# lakeplacidnews
# 710keel
# colombiareports
# joe
# journaltribune
# boston
# journal
# abc22now
# abc6onyourside
# cbs2iowa
# thereporter
# kxan
# wjhl
# rare
# trinidadexpress
# itv
# heraldsun
# timesleaderonline
# ktvu
# wnct
# csmonitor
# njherald
# newstalk
# nanowerk
# scienceblog
# enn
# bigislandnow
# iflscience
# chroniclelive
# 680news
# the-journal
# clarksvillenow
# mainebiz
# gq
# silive
# wcbi
# baseballnewssource
# rottentomatoes
# wcti12
# socialistworker
# inverelltimes
# latintimes
# 92moose
# blackpoolgazette
# executivebiz
# healthline
# dailymirror
# thespiritsbusiness
# burnleyexpress
# insurancejournal
# popularmechanics
# waaytv
# siliconrepublic
# weeklyblitz
# iisd
# avweb
# footballtransfertavern
# storypick
# talkingpointsmemo
# msnbc
# thespec
# plant
# malaymail
# thejakartapost
# metsmerizedonline
# tampabay
# caughtoffside
# laptopmag
# brooklynvegan
# nottinghampost
# slate
# publicnewsservice
# cyprus-mail
# the-star
# in-cumbria
# accountingtoday
# thetablet
# bangordailynews
# tvnz
# capitolhillblue
# theyeshivaworld
# reason
# dailyeasternnews
# thescore
# gamasutra
# football365
# virtual-strategy
# thenationonlineng
# wetinhappen
# gamingintelligence
# edmontonexaminer
# businesswire
# lexblog
# ua
# tvguide
# historynewsnetwork
# rushthekop
# canadianarchitect
# koimoi
# labiotech
# dealerscope
# macrumors
# sleepreviewmag
# research-live
# theonlinecitizen
# frontpagemag
# mobilenewscwp
# theprideoflondon
# theindianalawyer
# lifesitenews
# runnersworld
# lareviewofbooks
# thirdsector
# bhatkallys
# uinterview
# artvoice
# defensesystems
# fcw
# peoplesworld
# statnews
# globalsecurity
# buffalo
# busseltonmail
# keyc
# nbcchicago
# nbcphiladelphia
# nbcwashington
# talkbusiness
# laist
# justsecurity
# acs
# dealstreetasia
# winteriscoming
# myspace
# sciencefiction
# globalissues
# themreport
# northafricapost
# newsy
# mynewsdesk
# boatingindustry
# therealdeal
# 247wallst
# perishablenews
# ecowatch
# mediaupdate
# nst
# smartcompany
# themandarin
# autoremarketing
# wheels24
# newsgram
# pymnts
# newschannel9
# plos
# closerweekly
# nebraska
# hollywood
# newstodaynet
# palmbeachdailynews
# calbears
# chathamdailynews
# thesudburystar
# stereogum
# ibj
# ringsidereport
# thedailystar
# thelibertarianrepublic
# jordantimes
# ecr
# thecitizen
# enca
# hrw
# businesstech
# hongkongfp
# kelownanow
# sys-con
# hookem
# thewrap
# theproducenews
# ekantipur
# cpr
# thesource
# gossiponthis
# japantoday
# insideworldfootball
# krod
# assamtribune
# thecrimson
# canadianunderwriter
# ucdavis
# bodyandsoul
# citypages
# blackagendareport
# bernews
# elitedaily
# whittierdailynews
# rugbyworld
# portnews
# americanthinker
# yardbarker
# channelguidemag
# bamsmackpow
# hillsnews
# muslimnews
# elystandard
# theindychannel
# tasteofcountry
# popcrush
# mediapost
# pasadenastarnews
# sbsun
# lep
# thejambar
# wfit
# kentonline
# theverge
# deadspin
# elitesportsny
# businessfacilities
# areadevelopment
# reporterherald
# useventing
# flaglerlive
# collider
# jns
# desimartini
# steelersdepot
# nehandaradio
# victorharbortimes
# tenterfieldstar
# bellingencourier
# gleninnesexaminer
# guyraargus
# channel24
# scmagazineuk
# yaledailynews
# imediaethics
# themoderatevoice
# timesonline
# fox8live
# cfo
# sydneyswans
# planetf1
# buffalorising
# lowellsun
# thevalleydispatch
# dailysportscar
# bobfm
# thelumberjack
# all4women
# thelinkpaper
# inhomelandsecurity
# standard-freeholder
# rustourismnews
# dailygazette
# publishersweekly
# bostonmagazine
# bankerandtradesman
# bondbuyer
# tuftsdaily
# thecork
# parramattasun
# orissadiary
# coventrytelegraph
# bloodyelbow
# naturalgasintel
# rfa
# palatepress
# khmertimeskh
# oann
# fxstreet
# forexcrunch
# globalresearch
# poundsterlinglive
# canadafreepress
# hstoday
# southcoastregister
# themacweekly
# radiotimes
# wkbw
# twice
# pcmag
# stockznews
# crainsnewyork
# electronicdesign
# crossrhythms
# norwalkreflector
# davaotoday
# slashfilm
# splicetoday
# gamespot
# naija247news
# technode
# city-journal
# rhymejunkie
# trust
# goodmenproject
# bigblueview
# tribuneonlineng
# nola
# freakonomics
# petaluma360
# rushlimbaugh
# adn
# econintersect
# iranian
# themonitor
# fosters
# koaa
# 14news
# kplctv
# walb
# wtvm
# ksla
# newschannel10
# wave3
# wect
# kolotv
# rugby
# nationalclubgolfer
# thewire
# mainstreamweekly
# thebetterindia
# europeansting
# theeyeopener
# radioandmusic
# africanews
# pendletoday
# occrp
# fin24
# northwestern
# eurasiareview
# ftadviser
# chesterstandard
# stepfeed
# the72
# nmfc
# mmafighting
# mmamania
# redlandsdailyfacts
# joblo
# olympic
# star2
# rcinet
# wksu
# wuft
# houstonpublicmedia
# ideastations
# wabe
# homelandprepnews
# williamsondailynews
# newportbeachindy
# dailyrecord
# nagalandpost
# nationalreview
# psmag
# hcplive
# time
# harvard
# lutontoday
# wowt
# kjrh
# mpnews
# vulture
# fatherly
# abc15
# turnto23
# wvmetronews
# seacoastonline
# pmnewsnigeria
# kiiitv
# haaretz
# pineisland-eagle
# voiceonline
# kitco
# bworldonline
# legaluspokersites
# thepacker
# computerweekly
# conservativehome
# skynews
# lordsofpain
# nwahomepage
# prlog
# shape
# hyperallergic
# arstechnica
# fiveaa
# cio
# towleroad
# healthcarefinancenews
# tuko
# thehitavada
# slantmagazine
# lgbtqnation
# scarymommy
# gatorsports
# arkansasrazorbacks
# kait8
# edweek
# news4jax
# rferl
# mst
# rollingout
# playbill
# mixdownmag
# india-forums
# rockchalktalk
# chicagobusiness
# plasticsnews
# setexasrecord
# oberonreview
# theintell
# thisisanfield
# looktothestars
# miaminewtimes
# thesandb
# twinfinite
# worthplaying
# stevivor
# tehelka
# mpnnow
# insideedition
# kilburntimes
# manmonthly
# pinkun
# themonthly
# undercurrentnews
# neowin
# footwearnews
# cmswire
# texastribune
# ktsa
# comicsbeat
# dailysignal
# insidehighered
# totalprosports
# recode
# pwmania
# chorley-guardian
# fleetwoodtoday
# lythamstannesexpress
# thevisitor
# limerickleader
# thesil
# brightonandhovenews
# midhurstandpetworth
# midsussextimes
# mv-voice
# dailynexus
# hitconsultant
# khn
# capitolfax
# teamusa
# thefridaytimes
# nyulocal
# northboundasia
# qnews
# reneweconomy
# giants
# dailylife
# glamour
# thesportreview
# jewishpress
# koreaherald
# fox4now
# esquire
# aclunc
# idahostatesman
# fox6now
# kcchronicle
# ndsmcobserver
# musicbusinessworldwide
# completemusicupdate
# cyclingtips
# ksfy
# wmfd
# mauinews
# claimsjournal
# thelcn
# wishtv
# wwnytv
# wtoc
# ktre
# tucsonnewsnow
# wflx
# timesbulletin
# news-gazette
# fortune
# cantondailyledger
# wkbn
# worldcrunch
# bt
# sconews
# uwyo
# whattheythink
# neoskosmos
# yallpolitics
# gaytimes
# bnonews
# gurufocus
# thefrisky
# cilisos
# jckonline
# harvardmagazine
# thecharlottepost
# kaaltv
# columbiaspectator
# sheknows
# leamingtonobserver
# click2houston
# peoplespunditdaily
# udaipurkiran
# sundaytimes
# bandt
# stv
# manchesterjournal
# troymedia
# bearingarms
# theregister
# wlfi
# ontario
# pastemagazine
# colombopage
# themillions
# mvariety
# satellitetoday
# remonline
# consumerelectronicsnet
# sdtimes
# fcnp
# pekintimes
# energeticcity
# nationalobserver
# marketrealist
# middleeastmonitor
# 943thepoint
# wobm
# nearshoreamericas
# sunherald
# glasgowsouthandeastwoodextra
# caribbeanlifenews
# nycaribnews
# kxlf
# multichannel
# americanbazaaronline
# swimmingworldmagazine
# rhinotimes
# thegauntlet
# thefourohfive
# com-unik
# komonews
# ksn
# wbtw
# texomashomepage
# kxxv
# neworleanscitybusiness
# sfreporter
# boxinginsider
# themag
# cricketworld
# sportsnewsireland
# mdcoastdispatch
# clubindustry
# barrons
# mandatory
# 964eagle
# tahawultech
# etftrends
# prevention
# merinews
# israelnationalnews
# allure
# traveller
# indaily
# patch
# healthnewsdigest
# tvseriesfinale
# infectioncontroltoday
# wcpo
# sciencemag
# wtva
# wktv
# kdrv
# kezi
# livescience
# space
# businessrecord
# insidethemagic
# bristolpost
# investorplace
# breakingdefense
# fox13news
# premiumtimesng
# motoringresearch
# bmmagazine
# umkc
# 620ckrm
# justia
# theindependent
# modernhealthcare
# un
# dailypakistan
# blayneychronicle
# trussvilletribune
# riotimesonline
# movieweb
# catholicherald
# catholicnewsagency
# catholic
# thebostonpilot
# mit
# fashionbeans
# greentechmedia
# communitynewspapers
# waynepost
# azcapitoltimes
# gloucestershirelive
# hillsdalecollegian
# philasun
# rep-am
# kjct8
# usc
# nvi
# dungogchronicle
# robesonian
# todaysconveyancer
# heatnation
# beyondtheflag
# thetransferrumourmill
# agrinews-pubs
# jambase
# jambands
# sportspromedia
# vindy
# dailyreporter
# dailymail
# malaya
# warontherocks
# moneylife
# cricket365
# sportsjoe
# lawandcrime
# dekhnews
# institutionalinvestor
# worldoil
# rigzone
# ultimateclassicrock
# ancient-origins
# msstate
# wearegreenbay
# chortle
# covnews
# ghananewsagency
# centralchronicle
# neonnettle
# thestranger
# adweek
# nan
# americasquarterly
# tcbmag
# keysnews
# newsone
# forward
# reformer
# benningtonbanner
# ulladullatimes
# lithgowmercury
# communitynews
# areanews
# startsat60
# dailygalaxy
# sciencealert
# cosmosmagazine
# ktiv
# balls
# thestate
# milehighreport
# bridlingtonfreepress
# bankrate
# capitalxtra
# northeasttoday
# publishersmarketplace
# eclectablog
# filmschoolrejects
# rabble
# adnews
# axisoflogic
# bclions
# actionforex
# nyoooz
# theindianawaaz
# northumberlandgazette
# theinertia
# opendemocracy
# cachevalleydaily
# foxla
# thebiglead
# somd
# lakesmail
# fayettevilleflyer
# philboxing
# 2oceansvibe
# thefinancialexpress
# braidwoodtimes
# esperanceexpress
# wkyt
# sundayobserver
# redressonline
# washingtonmonthly
# pak1stanfirst
# thetidenewsonline
# warc
# wfpl
# patentlyapple
# thenextweb
# ctv
# columbia
# crozetgazette
# thefashionspot
# nonprofitquarterly
# uiowa
# wgnradio
# telugu360
# popdust
# nevadabusiness
# lufkindailynews
# econtentmag
# sandiegoreader
# ukrinform
# morningstaronline
# marxist
# the-riotact
# asiaone
# prolificnorth
# miningjournal
# datacenterknowledge
# newyorkupstate
# abc3340
# fox11online
# kfdm
# klewtv
# kpic
# local12
# myfox28columbus
# news4sanantonio
# nbcmontana
# whatinvestment
# managingmadrid
# newyorkjets
# grandprix
# dallasobserver
# wsls
# netindian
# mining
# interaksyon
# pitchfork
# vitalfootball
# cricket
# thinkprogress
# abc27
# comeonboro
# dublinlive
# medscape
# easthamptonstar
# motherjones
# hawkeyenation
# dailyinterlake
# highpointpanthers
# easternriverinachronicle
# abccolumbia
# politifact
# oxfordamerican
# goingconcern
# digitalhealth
# bcheights
# vermontbiz
# fox45now
# ktvl
# valleycentral
# theintermountain
# ktnv
# stawelltimes
# football
# panthers
# nysportsday
# afc
# longfordleader
# themarketsdaily
# pctonline
# wnewsj
# kgmi
# pattayamail
# lasentinel
# doncasterfreepress
# uppermichiganssource
# junkee
# essence
# indianapublicmedia
# catscratchreader
# darkreading
# houstonpress
# record-bee
# blackenterprise
# greatyarmouthmercury
# wncn
# westword
# phoenixnewtimes
# lowyinterpreter
# thesaturdaypaper
# chicagoreader
# standardbredcanada
# collegehockeynews
# theobserver
# usmagazine
# eurasianet
# bluemountainsgazette
# governing
# horseracing
# chad
# hucknalldispatch
# boxingscene
# grimsbytelegraph
# stylecaster
# filmfare
# goldengatexpress
# newswest9
# newyorker
# wideopencountry
# dailyliberal
# wellingtontimes
# berkshireeagle
# sportinglife
# ellsworthamerican
# refinery29
# grist
# ncronline
# goduke
# eveningtribune
# mcdonoughvoice
# goldrushcam
# wegotthiscovered
# ejpress
# azpbs
# alarabiya
# farmersjournal
# brightonandhoveindependent
# footballfancast
# rutgers
# venturesafrica
# bgnews
# decider
# vanyaland
# undertheradarmag
# highsnobiety
# cuatower
# fwweekly
# insiderlouisville
# bizbash
# statepress
# sen
# carscoops
# capecod
# metalinjection
# azbigmedia
# bigissue
# novanewsnow
# ufc
# maxboxing
# teamtalk
# richmondfc
# paulickreport
# aseaofblue
# northbynorthwestern
# cavaliersnation
# poynter
# lbpost
# newhavenindependent
# aarp
# marshallindependent
# wxyz
# maizenbrew
# thedailynews
# comingsoon
# canoncitydailyrecord
# journal-advocate
# daventryexpress
# camdencourier
# colby
# travelpulse
# whnt
# mysinchew
# wilsontimes
# keepthefaith
# itnews
# factmag
# splinternews
# citybeat
# everydayhealth
# kxii
# georgiabulletin
# lemarssentinel
# fox5ny
# thepoke
# just-auto
# laweekly
# ucsusa
# live5news
# fabiusmaximus
# golocalprov
# registerstar
# thedailymail
# hometownfocus
# thecarexpert
# weeklytimesnow
# peterboroughtoday
# cambridge-news
# phonearena
# temple-news
# obrag
# chalkbeat
# silverscreen
# londonlovesbusiness
# melbournefc
# insidephilanthropy
# dancingastronaut
# theslanted
# marketing-interactive
# binarytribune
# thedailybanter
# spacenews
# campaignlive
# paralympic
# pghcitypaper
# webcenter11
# asumag
# usatodayhss
# princeton
# loyolamaroon
# thebatavian
# herald
# aftermarketnews
# golfmagic
# paddocktalk
# baynature
# sportscafe
# allaboutjazz
# 15rounds
# pri
# asianjournal
# simcoe
# yourstory
# middletowntranscript
# thelensnola
# cdapress
# aerotechnews
# biv
# fftimes
# economywatch
# catholicculture
# theliberal
# ctmirror
# govtech
# automationworld
# parkcitiespeople
# wjhg
# ntdaily
# birminghamtimes
# domain-b
# getmoresports
# impartialreporter
# whbl
# wtvbam
# portstephensexaminer
# jis
# baystatebanner
# marketplace
# washingtonpost
# thecut
# chattanoogan
# sussexexpress
# profootballhof
# seekingalpha
# cuny
# iowapublicradio
# publicradioeast
# azjewishpost
# thedmonline
# statesboroherald
# newstalkkgvo
# onclive
# wsfa
# dailytexanonline
# prowrestling
# bucsnation
# musicweek
# voiceofsandiego
# qz
# mountroyalsoccer
# wweek
# piercecountyherald
# newrichmond-news
# rivertowns
# peninsuladailynews
# wcmessenger
# virginia
# mix957gr
# camdennewjournal
# cricketcountry
# islingtongazette
# stornowaygazette
# ucla
# citylimits
# aww
# norfolkdailynews
# hiphopwired
# turnto10
# wgme
# whtc
# ft
# chestnuthilllocal
# pittnews
# engineering
# waff
# realgm
# beaconhilltimes
# eastcountymagazine
# computerworld
# techworld
# owensoundsuntimes
# ticotimes
# bleedinggreennation
# thetyee
# canoe
# realtor
# bavarianfootballworks
# theexaminer
# patriots
# nike
# thetower
# firehouse
# localmemphis
# galesburg
# goerie
# bigcountryhomepage
# mytwintiers
# tristatehomepage
# wearecentralpa
# lajuntatribunedemocrat
# wkrn
# wric
# mypanhandle
# siouxlandmatters
# your4state
# conchovalleyhomepage
# dothanfirst
# ozarksfirst
# kten
# fox5dc
# golfweek
# thewhig
# insidesources
# securityinfowatch
# yourmoney
# cam
# cnsnews
# wvik
# journal-topics
# rbth
# leoweekly
# finextra
# si
# local10
# apparelnews
# vaildaily
# boorowanewsonline
# peacefmonline
# borderchronicle
# centralwesterndaily
# empireofthekop
# dailycal
# moultrienews
# airdrieecho
# clintonnewsrecord
# cochranetimes
# delhinewsrecord
# fairviewpost
# fortmcmurraytoday
# gananoquereporter
# hannaherald
# lacombeglobe
# lakeshoreadvance
# leducrep
# nipawinjournal
# pinchercreekecho
# sherwoodparknews
# sprucegroveexaminer
# thelondoner
# thepost
# whitecourtstar
# parkrecord
# porkbusiness
# portadowntimes
# scotscoop
# araratadvertiser
# atlantafalcons
# devondispatch
# edsonleader
# highrivertimes
# nugget
# shorelinebeacon
# strathroyagedispatch
# stthomastimesjournal
# thechronicle-online
# tillsonburgnews
# timminspress
# timminstimes
# kenoradailyminerandnews
# mayerthorpefreelancer
# stratfordbeaconherald
# commonwealmagazine
# henricocitizen
# newsclick
# philadelphiaeagles
# tmj4
# hmenews
# artinfo
# tucsonweekly
# westernbulldogs
# winghamchronicle
# bigislandvideonews
# ekklesia
# nj1015
# driving
# industryweek
# defense
# mongabay
# fox2now
# kplr11
# wtvr
# forzaitalianfootball
# oyetimes
# juneauempire
# smdp
# tellymix
# thenewcivilrightsmovement
# kxl
# aikenstandard
# thewest
# wickedlocal
# kmaland
# ocj
# thetimes
# eastbayexpress
# proshareng
# hiphopdx
# bonnercountydailybee
# intrafish
# tnp
# sanmarinotribune
# yourdailyjournal
# saints
# ai-cio
# gossipcop
# manutd
# igeeksoccer
# cricbuzz
# lasvegasweekly
# dailypress
# vegnews
# beckershospitalreview
# americanfreepress
# garstangcourier
# lancasterguardian
# onthewight
# gqindia
# dal
# kpel965
# bizwest
# alibi
# slguardian
# footballgossip
# sdnews
# tradeonlytoday
# moreechampion
# wwgp1050
# cafemom
# myrecordjournal
# anglocelt
# kitv
# mihomepaper
# stockandland
# stockjournal
# foodnavigator-usa
# hackneygazette
# nationalmemo
# the-scientist
# riverdalepress
# krgv
# kttc
# wgem
# kutv
# wlos
# sportsvideo
# forsythnews
# katu
# foodbusinessnews
# mbtmag
# woai
# reliefweb
# bleepingcomputer
# bristol247
# camdenadvertiser
# macarthuradvertiser
# flavorwire
# mediamatters
# utahpolicy
# guns
# clarksvilleonline
# wtok
# mininggazette
# autoweek
# ilkestonadvertiser
# ripleyandheanornews
# wtam
# musketfire
# coloradoindependent
# golf
# logisticsviewpoints
# glamourmagazine
# channelbuzz
# wesleyanargus
# epmag
# tamilnet
# silverscreenandroll
# tigernet
# kktv
# endpts
# easternecho
# azdesertswarm
# pleasantonweekly
# njspotlight
# newscenter1
# kivitv
# wayneindependent
# crookstontimes
# onenewsnow
# wtnh
# lse
# neconnected
# southyorkshiretimes
# fiercehealthcare
# brewbound
# kqed
# nevadadailymail
# wsj
# indianapolismonthly
# brokernews
# sungazette
# espnfc
# dirtysouthsoccer
# medindia
# westernadvocate
# yukon-news
# businessnewswales
# mnnonline
# mmajunkie
# shponline
# thenewsnigeria
# informationng
# tv360nigeria
# urbanislandz
# clickorlando
# 107jamz
# hogshaven
# newburytoday
# santamariasun
# sonomanews
# 49ers
# bleedcubbieblue
# dailyutahchronicle
# daily49er
# marketrasenmail
# azom
# kdal610
# kelo
# financialreporter
# radiox
# kjzz
# charismamag
# palatinate
# thenewspaper
# northcoastjournal
# 41nbc
# wyrk
# dailymaverick
# thelantern
# phillymag
# mondovisione
# charlestoncitypaper
# emirates247
# loverugbyleague
# dailyedge
# intpolicydigest
# channelpartnersonline
# defenceweb
# northsomersettimes
# kicks105
# presstv
# fortsaskatchewanrecord
# mitchelladvocate
# nantonnews
# saultthisweek
# seaforthhuronexpositor
# lucknowsentinel
# vulcanadvocate
# unhcr
# maysville-online
# dailyadvertiser
# dglobe
# jacarandafm
# celebsnow
# ukiahdailyjournal
# mlssoccer
# farminguk
# manchester
# airspacemag
# fastcolabs
# business
# ktar
# broadway
# roodepoortrecord
# 4bc
# iihf
# sakshipost
# grubstreet
# okayplayer
# whatsontv
# scoregolf
# begadistrictnews
# edenmagnet
# wbrc
# 700wlw
# nfl
# abovethelaw
# citylab
# racerxonline
# arkansasbusiness
# greenun24
# knoe
# theitem
# lisburntoday
# semissourian
# waer
# wytv
# sounderatheart
# navasotaexaminer
# care2
# crainscleveland
# whitecenterblog
# defenceaviationpost
# racintoday
# entertainment-focus
# techcrunch
# libn
# sportsnaut
# dunmowbroadcast
# ksnt
# estateagenttoday
# centraljersey
# longwarjournal
# sidelionreport
# standardnewswire
# mysuncoast
# gcaptain
# energyvoice
# geektyrant
# wisc
# chrisd
# golfdigest
# ilfordrecorder
# eastbourneherald
# retail-week
# swlondoner
# houstontexans
# downtoearth
# bakercityherald
# thedailyrecord
# photonicsonline
# interestingengineering
# getreading
# sbts
# gamingbolt
# msbusiness
# cfl
# dailynorthwestern
# sbnation
# agri-pulse
# 1011now
# nbc26
# mudgeeguardian
# nynganobserver
# youngwitness
# thecomet
# intergameonline
# igamingbusiness
# gostanford
# automotiveworld
# drovers
# cattlenetwork
# justarsenal
# self
# tomsguide
# wibc
# longislandpress
# cagesideseats
# rap-up
# fightnews
# summitdaily
# koptalk
# blackburnnews
# teslarati
# splcenter
# optics
# thefifthestate
# audaud
# thecollegevoice
# wagingnonviolence
# siliconindia
# elleuk
# times-age
# xxlmag
# armidaleexpress
# walchanewsonline
# wctv
# thetrucker
# kget
# merrittherald
# trucknews
# tennis
# danspapers
# wilsoncountynews
# altpress
# delawarepublic
# sevendaysvt
# larrybrownsports
# derehamtimes
# fakenhamtimes
# thedrive
# guitarworld
# premierguitar
# yorkshireeveningpost
# uscho
# outsideonline
# thejetpress
# paloaltoonline
# neurologyadvisor
# newshounds
# lightreading
# northweststar
# psychcentral
# worldfinance
# duboiscountyherald
# ncpolicywatch
# msmagazine
# indiatvnews
# legalnewsline
# evolutionnews
# wincountry
# thrillist
# trektoday
# avinteractive
# cape-coral-daily-breeze
# lehighacrescitizen
# fortmyersbeachtalk
# arlingtontimes
# itweb
# journalpatriot
# energy
# piquenewsmagazine
# sunraysiadaily
# wmagazine
# yourdailyglobe
# naturalnews
# decaturish
# fox4news
# trinitynews
# gopride
# themobileindian
# malaysiakini
# wsav
# counton2
# myhighplains
# newrepublic
# kadn
# packers
# crikey
# allhiphop
# crash
# defensenews
# ifamagazine
# doverpost
# theunion
# whyallanewsonline
# odishasuntimes
# itworldcanada
# crosscut
# todayfm
# 98fm
# architectureanddesign
# mingtiandi
# tribtoday
# nyasatimes
# just-style
# umich
# stolaf
# capecodtoday
# mauinow
# wealthmanagement
# wbsm
# azcardinals
# outsidethebeltway
# skift
# threatpost
# nevadaappeal
# obj
# marshallnews
# bestofneworleans
# theenergycollective
# thewhistler
# antiwar
# healthcareitnews
# umass
# buckscountycouriertimes
# flagpole
# wvrecord
# deadlinedetroit
# liherald
# usni
# huntingtonnews
# wabi
# thelancasternews
# themanufacturer
# australianaviation
# punditarena
# northern-scot
# iranhumanrights
# wustl
# insidermedia
# haitiantimes
# meforum

# %% [markdown]
# Tentative selection of sites (selected because of foucs on one topic): --> bad idea
#
# - Business: businessinsider, marketwatch
# - Art/Cutlure: filmthreat, comicbook, billboard
# - Lifestyle/fashion: mamamia, vanityfair, teenvogue, vogue, healthcaredive
# - Politics: ipolitics
# - Tech: geek, cultofmac
# - Sport: espncricinfo, motorsport

# %% [markdown]
# Seems a bit hard to hand select from list.\
# Instead, I took the wikipedia subcategories of "journalism" and tried to find a couple specialised news sources in each field.
# Some sources used:
# https://en.wikipedia.org/wiki/List_of_business_newspapers \
# https://en.wikipedia.org/wiki/List_of_magazines_by_circulation#United_States \
# https://www.allyoucanread.com/magazines/ \
# https://en.wikipedia.org/wiki/List_of_scientific_journals \
# https://en.wikipedia.org/wiki/List_of_science_magazines \
#
# Or just search "list of ... magazines"
#
# - **Arts**:
# Alta Journal, Billboard Magazine, Architectural Digest, Juxtapoz, Art in America, AntiqueWeek, Antique Trader, ArtNews, Pastel Journal, Southwest Art
# - **Business**:
# Nihon Keizai Shimbun (Japan, see if there is), Financial Times, The Wall Street Journal, The Economist, The Economic Times (India), Il Sole 24 Ore (Italy), Mint, Business Standard, The Australian Financial Review, Inside Business, Forbes Business Insider, Money, Fortune, Bloomberg Businessweek
# - **Entertainment**:
# Entertainment Tonight, The Hollywood Reporter, Variety, Better Homes And Gardens, Game Informer Magazine, Good Housekeeping, Southern Living, Men's Health, Car and Driver, Motor Trend, People, Rolling Stone, The New Yorker, US Weekly
# - **Environment**:
# National Geographic, Nature Conservancy, National Wildlife, Sierra, Mother Earth News
# - **Fashion**:
# Vogue, Elle, Harper's Bazaar, Cosmopolitan, Business of Fashion, W, Allure, Grazia, Marie Claire, Vanity Fair, InStyle, Seventeen, Glamour, W, GQ
# - **Medicine**:
# WebMd, Psychology Today, Stanford Medecine Magazine, Harvard Medicine Magazine
# - **Music**:
# Mojo, Stereogun, The Quietus, Pitchfork, Spin, The Fader, Consequence of Sound
# - **Politics**:
# - **Science**:
# Popular science, Wired, PCMag, ComputerWorld, MIT Technology Review, Popular Mechanics, American Scientist, Psychology Today, Smithsonian, Science News, Nature, Discover,
# - **Sports**:
# ESPN, Sports Illustrated, Golf Digest, Slam, Tennis, The Red Bulletin, Baseball America

# %% [markdown]
# ## Task 4: Find topic in URL
#
# - Define a list of categories, and matching words that could indicate the category
# - Make this list "general" so that variants of the words can be found (ex: design, designer, designing... could all be classified in the same topic)
# - Check each url for possible matches (for that, the url words also need to be "generalised")
# - Add tag to url

# %% [markdown]
# Create a dictionary with terms to search
# - arts: visual arts, film, literature, music, theater, architecture
# - business: economic, financial
# - entertainment: lifestyle, television, film, theater music, video game, celebrity
# - environment: nature, climate
# - fashion: clothes,
# - medicine: health, wellbeing
# - music
# - politics: political, government, policy
# - science
# - sports : list of sports?
# -

# %% [markdown]
# ### Create discitionary of topics for classifying the urls

# %%
# Create a dictionary: to modify 

tag_list = ["art", "business", "entertainment", "environment" ...]
matchers = {"art": ["art", "paint", "draw"], "business": ["business", "finance", "economy"] ...}

# %% [markdown]
# ^ Problem: how to define this list?

# %% [markdown]
# ### Check that dictionary is generlized enough

# %%
stemmer = PorterStemmer() #will find the "general" version of a word

def tokenize(text):
    text = "".join([ch for ch in text if ch not in string.punctuation]) # get the text without punctuation
    tokens = nltk.word_tokenize(text) #Tokenizers divide strings into lists of substrings
    return " ".join([stemmer.stem(word.lower()) for word in tokens if word not in stopwords.words('english')]) #stem all words

# %%
# Example
test = 'Hello everyone my names are fancy potatoes and the sky''s colors are beautiful tonight'
tokenize(test)
# Out:
# 'hello everyon name fanci potato ski color beauti tonight'

# %%
def generalizeDictionary(matchers):
    for category in matchers:
        for i in range(len(matchers[category])):
            matchers[category][i] = tokenize(matchers[category][i])
            
            
# Example
matchers = {"art": ["art", "paint", "draw"], "business": ["business", "finance", "economy"]}
generalizeDictionary(matchers)
print('Generalized dictionary is:\n', matchers)
# Out:
# Generalized dictionary is:
#  {'art': ['art', 'paint', 'draw'], 'business': ['busi', 'financ', 'economi']}

# %% [markdown]
# ### Split URL into words

# %%
def getWordsFromURL(url):
    return re.compile(r'\W+',re.UNICODE).split(url)

# %%
test_url = df_test2['urls'][0][0]
getWordsFromURL(test_url)
# Out:
# ['http',
#  'www',
#  'ivpressonline',
#  'com',
#  'news',
#  'local',
#  'ivc',
#  'foundation',
#  'to',
#  'house',
#  'homeless',
#  'students',
#  'article_61ff9aa4',
#  'ee30',
#  '11e9',
#  '8ae9',
#  'b37ec7cd9579',
#  'html']

# %% [markdown]
# ### Generalize words in url

# %%
# Example
general_url = [tokenize(x) for x in getWordsFromURL(test_url)]
general_url
# Out:
# ['http',
#  'www',
#  'ivpressonlin',
#  'com',
#  'news',
#  'local',
#  'ivc',
#  'foundat',
#  '',
#  'hous',
#  'homeless',
#  'student',
#  'article61ff9aa4',
#  'ee30',
#  '11e9',
#  '8ae9',
#  'b37ec7cd9579',
#  'html']

# %% [markdown]
# ### Check if word from list is in *generalized* url

# %%
def classify(matchers, url): #Give it an already generalized dictionary
    tag_found = []
    general_url = [tokenize(x) for x in getWordsFromURL(url)]
    for category in matchers:
        for i in range(len(matchers[category])):
            match = matchers[category][i]
            if match in general_url:
                tag_found.append(category)
    return tag_found # or you can "return None"

# %%
# Example
matchers = {"art": ["art", "paint", "draw"], "business": ["business", "finance", "economy"], "sport": ["sport", "football"]}
test_url = df_test2['urls'][1][0] #contains 'business'

#Generalize dictionary before sending it to the classify() function
generalizeDictionary(matchers)
classify(matchers, test_url)
# Out:
# ['business']

# %%
# Add tag to dataframe

tags_column = [] # List of lists. Each list inside corresponds to a row. Will become the 'tag' column
for index, row in df_test2.iterrows():
    tags = [] #tags for all the urls in that row
    for url in row['urls']:
        categories = classify(matchers, url)
        tags.append(categories)
    tags_column.append(tags)

df_test2['tags'] = tags_column
df_test2
# Out:
#                 quoteID                                          quotation  \
# 0     2019-10-14-000009  % 9: D: D @? 6 H2J H6 E9@F89E H6 4@F=5 8: G6 3...
# 1     2019-04-08-048753       It is immoral. It is harmful. It is hurtful.
# 2     2019-07-17-000030        [ Amber ] loves her son more than anything,
# 3     2019-05-15-053302  It is important for our equine science student...
# 4     2019-04-20-000011  ... an Afrikaans family living in South Africa...
# ...                 ...                                                ...
# 9995  2019-06-13-115504  We have one match left here and I hope we can ...
# 9996  2019-04-02-062264  Jump in head-first; grab some options that cap...
# 9997  2019-03-14-121949  We have opportunities, we certainly have some ...
# 9998  2019-02-28-064897                      Jungle cruise coming to life,
# 9999  2019-02-27-120076  We have our own special wing. It's very beauti...
#
#                      speaker         qids                date  numOccurrences  \
# 0                       None           [] 2019-10-14 07:30:00               1
# 1     President Donald Trump     [Q22686] 2019-04-08 16:22:00              44
# 2                       None           [] 2019-07-17 22:54:35               1
# 3              Sally Johnson  [Q42336656] 2019-05-15 18:03:22               1
# 4                       None           [] 2019-04-20 22:30:57               1
# ...                      ...          ...                 ...             ...
# 9995           Yoon Deok-yeo    [Q487477] 2019-06-13 00:00:00               7
# 9996                    None           [] 2019-04-02 05:54:30               2
# 9997                    None           [] 2019-03-14 18:35:00               1
# 9998                    None           [] 2019-02-28 16:51:52               2
# 9999                    None           [] 2019-02-27 15:03:39               1
#
#                                                  probas  \
# 0             [[None, 0.5595], [Julio Morales, 0.4405]]
# 1     [[President Donald Trump, 0.5802], [None, 0.36...
# 2            [[None, 0.8276], [Amber Portwood, 0.1724]]
# 3             [[Sally Johnson, 0.5721], [None, 0.4279]]
# 4                  [[None, 0.8331], [you long, 0.1669]]
# ...                                                 ...
# 9995          [[Yoon Deok-yeo, 0.7274], [None, 0.2726]]
# 9996  [[None, 0.7858], [Duchess of Sussex, 0.1581], ...
# 9997             [[None, 0.5911], [Jim Cramer, 0.4089]]
# 9998  [[None, 0.8612], [Emily Blunt, 0.0725], [Dwayn...
# 9999  [[None, 0.4153], [Donald Trump, 0.3342], [Mela...
#
#                                                    urls phase  \
# 0     [http://www.ivpressonline.com/news/local/ivc-f...     E
# 1     [https://www.mercedsunstar.com/news/business/a...     E
# 2     [https://www.inquisitr.com/5535969/did-amber-p...     E
# 3     [https://www.lanereport.com/113381/2019/05/qua...     E
# 4        [http://filmthreat.com/reviews/the-harvester/]     E
# ...                                                 ...   ...
# 9995  [http://asia.eurosport.com/football/koreans-cl...     E
# 9996  [https://www.vogue.com.au/culture/racing-carni...     E
# 9997  [https://www.cnbc.com/2019/03/14/ge-ceo-culp-t...     E
# 9998  [https://comicbook.com/2019/02/28/the-rock-beh...     E
# 9999  [http://us.hellomagazine.com/homes/20190227702...     E
#
#                                                 domains  \
# 0                                                 [com]
# 1     [com, com, com, com, com, com, com, com, com, ...
# 2                                                 [com]
# 3                                                 [com]
# 4                                                 [com]
# ...                                                 ...
# 9995            [com, com, co.uk, com, com, co.ke, com]
# 9996                                   [com.au, com.au]
# 9997                                              [com]
# 9998                                         [com, com]
# 9999                                              [com]
#
#                                               sitenames  \
# 0                                       [ivpressonline]
# 1     [mercedsunstar, sacbee, mynorthwest, lasvegass...
# 2                                           [inquisitr]
# 3                                          [lanereport]
# 4                                          [filmthreat]
# ...                                                 ...
# 9995  [eurosport, eurosport, eurosport, eurosport, e...
# 9996                                     [vogue, vogue]
# 9997                                             [cnbc]
# 9998                             [comicbook, comicbook]
# 9999                                    [hellomagazine]
#
#                                                    tags
# 0                                                  [[]]
# 1     [[business], [business], [], [], [], [], [], [...
# 2                                                  [[]]
# 3                                                  [[]]
# 4                                                  [[]]
# ...                                                 ...
# 9995  [[sport], [sport], [sport], [sport], [], [], [...
# 9996                                           [[], []]
# 9997                                               [[]]
# 9998                                           [[], []]
# 9999                                               [[]]
#
# [10000 rows x 12 columns]

# %% [markdown]
# ### Check for tags in url and save tags

# %% [markdown]
# #### Option 1: write new file (also extracts domain and sitename)

# %%
import bz2
import json

path_to_file = 'data/quotes-2019.json.bz2' 
path_to_out = 'data/quotes-2019-domains-names.json.bz2'

matchers = {...} # dictionary to define
generalizeDictionary(matchers)

with bz2.open(path_to_file, 'rb') as s_file:
    with bz2.open(path_to_out, 'wb') as d_file:
        for instance in s_file:
            instance = json.loads(instance) # loading a sample
            urls = instance['urls'] # extracting list of links
            domains = []
            sitenames = []
            tags = []
            for url in urls:
                tld = get_domain(url)
                name = get_sitename(url)
                categories = classify(matchers, url)
                domains.append(tld)
                sitenames.append(name)
                tags.append(categories)
            instance['domains'] = domains # updating the sample with domain name
            instance['sitenames'] = sitenames # updating the sample with sitename
            instance['tags'] = tags # updating the sample with tags of topics
            d_file.write((json.dumps(instance)+'\n').encode('utf-8')) # writing in the new file

# %%
#with bz2.open(path_to_file, 'rb') as s_file:
with pd.read_json... #read the original file
    with bz2.open(path_to_out, 'wb') as d_file:
        #for instance in s_file:
        for chunk in df_chunk:
            #instance = json.loads(instance) # loading a sample
            chunk = process_chunk
            chunk.to_json
            d_file.write((json.dumps(instance)+'\n').encode('utf-8'))

# %% [markdown]
# #### Option 2: modify file opened in memory

# %%
matchers = {...} # dictionary to define
generalizeDictionary(matchers)

def process_chunk_tagging(chunk):
        print(f'Processing chunk with {len(chunk)} rows')
        tags_column = [] # List of lists. Each list inside corresponds to a row. Will become the 'tag' column
        for index, row in chunk.iterrows():
            tags = [] #tags for all the urls in that row
            for url in row['urls']:
                categories = classify(matchers, url)
                tags.append(categories)
            tags_column.append(tags)
        chunk['tags'] = tags_column
        

with pd.read_json(FILE_PATH, lines=True, compression='bz2', chunksize=1000000) as df_reader:
    for chunk in df_reader:
        process_chunk_tagging(chunk)
        
        
def process_chunk_urls(chunk):
        tags_column = [] # List of lists. Each list inside corresponds to a row. Will become the 'tag' column
        site_column = []
        domain_column = []
        for index, row in chunk.iterrows():
            tags = [] #tags for all the urls in that row
            domains = []
            sitenames = []
            for url in row['urls']:
                #Extract data
                tld = get_domain(url)
                name = get_sitename(url)
                categories = classify(matchers, url)
                #Append data
                domains.append(tld)
                sitenames.append(name)
                tags.append(categories)
            tags_column.append(tags)
            site_column.append(sitenames)
            domain_column.append(domains)
        # Create new columns with new data
        chunk['sitenames'] = site_column
        chunk['domain'] = domaine_column
        chunk['tags'] = tags_column

# %% [markdown]
# # Finding synonyms of words

# %%
import nltk
nltk.download()
from nltk.corpus import wordnet
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
synonyms = []
antonyms = []

for syn in wordnet.synsets("business"):
    for l in syn.lemmas():
        synonyms.append(l.name())
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())

print(set(synonyms))
# Out:
# {'job', 'business_organization', 'business_concern', 'business_organisation', 'occupation', 'patronage', 'byplay', 'commercial_enterprise', 'business_sector', 'concern', 'line', 'business_enterprise', 'line_of_work', 'stage_business', 'business', 'clientele'}

# %%
# Creating a list of synonyms for the dicitionary

matchers = {"art": ["art", "paint", "draw"], "business": ["business", "finance", "economy"], "sport": ["sport", "football"]}

for category in matchers:
    synonyms = []
    for i in range(len(matchers[category])):
        word = matchers[category][i]
        for syn in wordnet.synsets(word):
            for l in syn.lemmas():
                synonyms.append(l.name())
        matchers[category] = synonyms

# %%
matchers
# Out:
# {'art': ['art',
#   'fine_art',
#   'art',
#   'artistic_creation',
#   'artistic_production',
#   'art',
#   'artistry',
#   'prowess',
#   'artwork',
#   'art',
#   'graphics',
#   'nontextual_matter',
#   'art',
#   'fine_art',
#   'art',
#   'fine_art',
#   'art',
#   'artistic_creation',
#   'artistic_production',
#   'art',
#   'artistry',
#   'prowess',
#   'artwork',
#   'art',
#   'graphics',
#   'nontextual_matter'],
#  'business': ['business',
#   'concern',
#   'business_concern',
#   'business_organization',
#   'business_organisation',
#   'commercial_enterprise',
#   'business_enterprise',
#   'business',
#   'occupation',
#   'business',
#   'job',
#   'line_of_work',
#   'line',
#   'business',
#   'business',
#   'business',
#   'business',
#   'business_sector',
#   'clientele',
#   'patronage',
#   'business',
#   'business',
#   'stage_business',
#   'byplay',
#   'concern',
#   'concern',
#   'care',
#   'fear',
#   'concern',
#   'concern',
#   'worry',
#   'headache',
#   'vexation',
#   'business',
#   'concern',
#   'business_concern',
#   'business_organization',
#   'business_organisation',
#   'refer',
#   'pertain',
#   'relate',
#   'concern',
#   'come_to',
#   'bear_on',
#   'touch',
#   'touch_on',
#   'have-to_doe_with',
#   'concern',
#   'interest',
#   'occupy',
#   'worry',
#   'business',
#   'concern',
#   'business_concern',
#   'business_organization',
#   'business_organisation'],
#  'sport': ['sport',
#   'athletics',
#   'sport',
#   'sport',
#   'summercater',
#   'sport',
#   'sport',
#   'sportsman',
#   'sportswoman',
#   'mutant',
#   'mutation',
#   'variation',
#   'sport',
#   'fun',
#   'play',
#   'sport',
#   'sport',
#   'feature',
#   'boast',
#   'frolic',
#   'lark',
#   'rollick',
#   'skylark',
#   'disport',
#   'sport',
#   'cavort',
#   'gambol',
#   'frisk',
#   'romp',
#   'run_around',
#   'lark_about',
#   'sport',
#   'athletics',
#   'athletic_contest',
#   'athletic_competition',
#   'athletics',
#   'athletics']}
